# %%
from PIL import Image
import random
end =100

def show_board():
    img = Image.open("image.jpg")
    img.show()

    
def play():
    p1_name = input("Player 1, Enter your name ")
    p2_name = input("Player 2, Enter your name ")
    p1 = 0
    p2 = 0
    turn = 0
    while (1):
        if turn % 2 == 0:
            print(p1_name, " your turn")
            c = input("Press 1 to continue, 0 to quit")
            if c == "0":
                print(p1_name," your score ", p1)
                print(p2_name," your score ", p2)
                print("quiting the game, thanks for playing")
                break
            else:
                dice = random.randint(0,6)
                print("dice shows ", dice)
                p1 = p1 + dice
                p1 = check_ladder(p1)
                p1 = check_snake(p1)
                print("your score is ", p1)
                if p1>end:
                    p1 = end
                    print(p1_name, " your socre ", p1)

                if reached_end(p1):
                    print(p1_name, " won ")
                    break
        else:
            print(p2_name, " your turn")
            c = input("Press 1 to continue, 0 to quit")
            if c == "0":
                print(p1_name," your score ", p1)
                print(p2_name," your score ", p2)
                print("quiting the game, thanks for playing")
                break
            else:
                dice = random.randint(0,6)
                print("dice shows ", dice)
                p2 = p2 + dice
                p2 = check_ladder(p2)
                p2 = check_snake(p2)
                print("your score is ", p2)
                if p2>end:
                    p2 = end
                    print(p2_name, " your socre ", p2)

                if reached_end(p2):
                    print(p2_name, " won ")
                    break
        
        turn += 1
        
        
        
def check_ladder(p):
    if p == 4:
        print('ladder')
        return 14 
    elif p ==9:
        print('ladder')
        return 31
    elif p == 20:
        print('ladder')
        return 38
    elif p== 28:
        print('ladder')
        return 76
    elif p == 32:
        print('ladder')
        return 51
    elif p == 37:
        print('ladder')
        return 56
    elif p == 40:
        print('ladder')
        return 42
    elif p == 61:
        print('ladder')
        return 82
    elif p == 71:
        print('ladder')
        return 91
    elif p == 86:
        print('ladder')
        return 96
    else:
        return p
    
    
    
def check_snake(p):
    if p == 98:
        print('snake')
        return 77
    elif p ==93:
        print('snake')
        return 72
    elif p == 87:
        print('snake')
        return 25
    elif p == 67:
        print('snake')
        return 52
    elif p == 62:
        print('snake')
        return 19
    elif p == 64:
        print('snake')
        return 60
    elif p == 54:
        print('snake')
        return 48
    elif p == 35:
        print('snake')
        return 8
    elif p == 73:
        print('snake')
        return 1
    elif p == 23:
        print('snake')
        return 3
    elif p == 17:
        print('snake')
        return 6
    else:
        return p
    
def reached_end(p):
    if p == end:
        return True
    else:
        return False
    
show_board()
play()
