# %%
import random
def computer():
    user_weapon  = input("Select from Rock, Paper and Scissors ").capitalize()
    weapons = ['Rock', "Paper", "Scissors"]
    computer_weapon = random.choice(weapons)
    if user_weapon == computer_weapon:
        print("Draw")
    elif user_weapon == "Rock" and computer_weapon == "Scissors":
        print("user wins!!")
    elif user_weapon == "Rock" and computer_weapon == "Paper":
        print("computer wins!!")
    elif user_weapon == "Paper" and computer_weapon == "Scissors":
        print("computer wins!!")
    elif user_weapon == "Paper" and computer_weapon == "Rock":
        print("user wins!!")
    elif user_weapon == "Scissors" and computer_weapon == "Rock":
        print("computer wins!!")
    elif user_weapon == "Scissors" and computer_weapon == "Paper":
        print("user wins!!")











def r_p_s(num1, num2, bit1, bit2):
    p1 = int(num1[bit1])%3
    p2 = int(num2[bit2])%3
    
    if player1[p1] == player2[p2]:
        print("Draw")
    elif player1[p1] == "Rock" and player2[p2] == "Scissors":
        print("player 1 wins!!")
    elif player1[p1] == "Rock" and player2[p2] == "Paper":
        print("player 2 wins!!")
    elif player1[p1] == "Paper" and player2[p2] == "Scissors":
        print("player 2 wins!!")
    elif player1[p1] == "Paper" and player2[p2] == "Rock":
        print("player 1 wins!!")
    elif player1[p1] == "Scissors" and player2[p2] == "Rock":
        print("player 2 wins!!")
    elif player1[p1] == "Scissors" and player2[p2] == "Paper":
        print("player 1 wins!!")

player1 = {0:"Rock", 
          1:"Paper",
          2:"Scissors"}
player2 = {2:"Rock", 
          1:"Paper",
          0:"Scissors"}
while(1):
    choice_play = int(input("Enter 1 for for play with friend\n2 play with computer  \n3 for quit\n"))
    if choice_play == 1:
        num1 = input("Player one, Enter your Choice")
        num2 = input("Player two, Enter your Choice")
        bit1 = int(input("Player 1, Enter the secret bit position"))
        bit2 = int(input("Player 2, Enter the secret bit position"))
        r_p_s(num1, num2, bit1, bit2)
        ch = input("Do you want to contine? y/n")
        if ch == "n":
            break
    elif choice_play == 2:
        computer()
    elif choice_play == 3:
        print("Thanks for playing")
        break
    else:
        print("Enter from the above options")
# Out:
# Enter 1 for for play with friend
# 2 play with computer
# 3 for quit
# 1
# Player one, Enter your Choice753
# Player two, Enter your Choice951
# Player 1, Enter the secret bit position2
# Player 2, Enter the secret bit position0
# player 1 wins!!
# Do you want to contine? y/nn
